# %%
7.4
things = ["mozzarella", "cinderella", "salmonella"]

# %%
7.5
things[1] = things[1].capitalize #python counts from 0,1,2 etc
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %%
7.6
things[0] = things[0].upper()
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %%
7.7
del things[2]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella']

# %%
9.1
def good():
    return ['Harry', 'Ron', 'Hermione']

# %%
9.2
def get_odds():
    for number in range(10):
        if number % 2 ==1:
            yield number

count = 0

for number in get_odds():
    count += 1 
    if count ==3:
        print(number)
# Out:
# 5
