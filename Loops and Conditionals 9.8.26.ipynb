# %%
4.1
secret = 6 
guess = 8
if guess < secret:
    print ("too low")
elif guess > secret:
    print ("too high")
else:
    print ("just right")
# Out:
# too high

# %%
4.2
small = True 
green = False
if small and green:
   print ("pea")
elif small and not green:
    print ("cherry")
elif not small and green:
    print ("Watermelon")
else: 
    print ("pumpkin")
# Out:
# cherry

# %%
6.1
nums = [3, 2, 1, 0]
for number in nums:
    print (number)
# Out:
# 3
# 2
# 1
# 0

# %%
6.2
guess_me = 7
number = 1

while True:
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
        break
    else:
        print("oops")
        break
        
    number = number + 1
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it!

# %%
6.3
guess_me = 5

for number in range(10):
    if number < guess_me:
        print("too low")
    elif number == guess_me:
        print("found it!")
        break
    else:
        print("oops")
        break
# Out:
# too low
# too low
# too low
# too low
# too low
# found it!
